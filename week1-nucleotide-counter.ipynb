# %% [markdown]
# <a href="https://colab.research.google.com/github/pipette2pipeline/learning-python-biology/blob/main/week1-nucleotide-counter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello from Colab")
